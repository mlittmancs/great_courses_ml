# %% [markdown]
# Make and run a goodbye(x,y) program that writes x copies of hello, followed by y copies of goodbye.

# %%
def goodbye(x,y):
  for i in range(x):
    print("hello")
  for i in range(y):
    print("goodbye")

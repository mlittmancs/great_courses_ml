# %%
def helloworld(x):
  for i in range(x):
    print("hello!")

# %%
helloworld(5)
# Out:
# hello!
# hello!
# hello!
# hello!
# hello!

# %%
4+5+
# Out:
#   File "<ipython-input-3-093f358e7dd5>", line 1
#     4+5+
#         ^
# SyntaxError: invalid syntax

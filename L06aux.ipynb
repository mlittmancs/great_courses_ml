# %%
import math

def shoot(angle):
  xpos = 10
  ypos = 50
  force = 2.3
  gravity = -1
  xvel = force*math.cos(angle/360.0*2*math.pi)
  yvel = force*math.sin(angle/360.0*2*math.pi)
  xtarget = 20
  timestep = 0.001
  while ypos > 0:
    xpos += xvel*timestep
    ypos += yvel*timestep
#    if xpos > 100: xvel = -xvel
    if xpos < 0: xvel = -xvel
    yvel += gravity*timestep
  return(abs(xpos-xtarget))
#  return(xpos)

steps = 3600
angles = [360.0*i/steps for i in range(steps)]
landing = [shoot(angle) for angle in angles]

# %%
import matplotlib.pyplot as plt

plt.scatter(angles, landing)
plt.title('Target distance')
plt.xlabel('angle')
plt.ylabel('distance')
plt.show()

# %%
def show(angle):
  xpos = 10
  ypos = 50
  force = 2.3
  gravity = -1
  xvel = force*math.cos(angle/360.0*2*math.pi)
  yvel = force*math.sin(angle/360.0*2*math.pi)
  xtarget = 20
  timestep = 0.001
  xs = [xpos]
  ys = [ypos]
  while ypos > 0:
    xpos += xvel*timestep
    ypos += yvel*timestep
#    if xpos > 100: xvel = -xvel
    if xpos < 0: xvel = -xvel
    yvel += gravity*timestep
    xs += [xpos]
    ys += [ypos]
  plt.scatter(xs, ys)
  plt.show()
show(320)

# %%
[(angles[i],landing[i]) for i in range(len(angles)) if landing[i] < 1]
# Out:
# [(67.3, 0.9581107966241262),
#  (67.4, 0.9132570024223341),
#  (67.5, 0.8692427244451331),
#  (67.6, 0.8251805020897471),
#  (67.7, 0.7810704589166164),
#  (67.8, 0.7369127186205127),
#  (67.9, 0.6927074051183766),
#  (68.0, 0.6475930472967519),
#  (68.1, 0.6032966830679243),
#  (68.2, 0.5589531210675887),
#  (68.3, 0.5145624859466267),
#  (68.4, 0.4701249025407961),
#  (68.5, 0.42479754306842565),
#  (68.6, 0.3802701745768857),
#  (68.7, 0.335696236005937),
#  (68.8, 0.2910758529399793),
#  (68.9, 0.24640915110985162),
#  (69.0, 0.20087201022363388),
#  (69.1, 0.15611679783103227),
#  (69.2, 0.11131564760778545),
#  (69.3, 0.06565569391077375),
#  (69.4, 0.020766804050754928),
#  (69.5, 0.02416764113297276),
#  (69.6, 0.06914751459909496),
#  (69.7, 0.11497064111667044),
#  (69.8, 0.1600372231427727),
#  (69.9, 0.2051488487996771),
#  (70.0, 0.2510920366673197),
#  (70.1, 0.29628959275185096),
#  (70.2, 0.34153180625606794),
#  (70.3, 0.38759386796209583),
#  (70.4, 0.4329212307189323),
#  (70.5, 0.47829286309908525),
#  (70.6, 0.524472606865146),
#  (70.7, 0.5699286043075844),
#  (70.8, 0.6161848752820092),
#  (70.9, 0.6617247117854106),
#  (71.0, 0.707308167337608),
#  (71.1, 0.7536801223105627),
#  (71.2, 0.7993466277471803),
#  (71.3, 0.8457937701972327),
#  (71.4, 0.8915427962310538),
#  (71.5, 0.9380645872681193),
#  (71.6, 0.9838956033488131),
#  (298.6, 0.9905884108890284),
#  (298.7, 0.959552548885636),
#  (298.8, 0.9296381747434559),
#  (298.9, 0.8986328455930277),
#  (299.0, 0.8676411834177955),
#  (299.1, 0.8377818675883475),
#  (299.2, 0.8068213691514465),
#  (299.3, 0.7770004378451745),
#  (299.4, 0.74607152134557),
#  (299.5, 0.7162893790148033),
#  (299.6, 0.6853924625166137),
#  (299.7, 0.6545099584262779),
#  (299.8, 0.6247850147960037),
#  (299.9, 0.5939351410323894),
#  (300.0, 0.5642499999981467),
#  (300.1, 0.5334331742995566),
#  (300.2, 0.5026312936581725),
#  (300.3, 0.4730048795033248),
#  (300.4, 0.4422366767811212),
#  (300.5, 0.4114837392791273),
#  (300.6, 0.381916970108076),
#  (300.7, 0.35119834009437767),
#  (300.8, 0.3204952953430791),
#  (300.9, 0.2909890885876365),
#  (301.0, 0.2603209806041704),
#  (301.1, 0.22966877781982475),
#  (301.2, 0.2002240501903252),
#  (301.3, 0.16960741310937877),
#  (301.4, 0.1390070010492046),
#  (301.5, 0.1096246684911506),
#  (301.6, 0.07906045072994061),
#  (301.7, 0.048512777661933626),
#  (301.8, 0.019193755399165013),
#  (301.9, 0.011317095148989154),
#  (302.0, 0.04181108143972523),
#  (302.1, 0.07228809575858719),
#  (302.2, 0.10152241496112424),
#  (302.3, 0.13196176725613995),
#  (302.4, 0.1623838282152974),
#  (302.5, 0.1927884901839434),
#  (302.6, 0.22193647269871875),
#  (302.7, 0.252302633803982),
#  (302.8, 0.2826510767690458),
#  (302.9, 0.31298169398862896),
#  (303.0, 0.3420417080901643),
#  (303.1, 0.3723329863369145),
#  (303.2, 0.4026061199079649),
#  (303.3, 0.43286100128605653),
#  (303.4, 0.4618314172415978),
#  (303.5, 0.4920461222936545),
#  (303.6, 0.5222422564728184),
#  (303.7, 0.5524197123018979),
#  (303.8, 0.5825783823523345),
#  (303.9, 0.611435345396842),
#  (304.0, 0.6415527916282748),
#  (304.1, 0.6716511337159119),
#  (304.2, 0.7017302642818777),
#  (304.3, 0.7317900759674778),
#  (304.4, 0.7618304614389757),
#  (304.5, 0.7905485790369013),
#  (304.6, 0.8205464838539704),
#  (304.7, 0.8505246445452492),
#  (304.8, 0.8804829538373156),
#  (304.9, 0.9104213044937985),
#  (305.0, 0.9403395893098292),
#  (305.1, 0.970237701108001)]

# %%
import random

population = [random.randint(0,3600)/10.0 for i in range(10)]
vals = [0 for i in population]

plt.scatter(angles, landing)
plt.scatter(population, vals)
plt.title('Target distance')
plt.xlabel('angle')
plt.ylabel('distance')
plt.show()

# %%
vals = [shoot(ang) for ang in population]

plt.scatter(angles, landing)
plt.scatter(population, vals)
plt.title('Target distance')
plt.xlabel('angle')
plt.ylabel('distance')
plt.show()

min(vals)
# Out:
# 6.086940043116371

# %%
import random
import statistics

threshold = statistics.median(vals)

population = [population[i] for i in range(len(population)) if vals[i] <= threshold]
vals = [shoot(ang) for ang in population]

plt.scatter(angles, landing)
plt.scatter(population, vals)
plt.title('Target distance')
plt.xlabel('angle')
plt.ylabel('distance')
plt.show()

# %%
kids = [ang + random.uniform(-5,5) for ang in population]
population = population + kids

vals = [shoot(ang) for ang in population]

plt.scatter(angles, landing)
plt.scatter(population, vals)
plt.title('Target distance')
plt.xlabel('angle')
plt.ylabel('distance')
plt.show()

min(vals)
# Out:
# 6.086940043116371

# %%
# animation

import math
import matplotlib.pyplot as plt

def traj(angle):
  xpos = 10
  ypos = 50
  force = 2.3
  gravity = -1
  xvel = force*math.cos(angle/360.0*2*math.pi)
  yvel = force*math.sin(angle/360.0*2*math.pi)
  xtarget = 20
  timestep = 0.001
  xs = [xpos]
  ys = [ypos]
  while ypos > 0:
    xpos += xvel*timestep
    ypos += yvel*timestep
#    if xpos > 100: xvel = -xvel
    if xpos < 0: xvel = -xvel
    yvel += gravity*timestep
    xs += [xpos]
    ys += [ypos]
  plt.plot(xs, ys)
  return(xpos)

# traj(15) # farthest out to the right
# traj(69) # hit target shooting up
# traj(110) # hit wall corner shooting up
# traj(165) # closest to target off wall
# traj(240) # hit wall corner shooting down
# traj(302) # hit target shooting down
traj(180)
traj(60)
traj(280)
plt.scatter([20], [0])
plt.show()

# plt.scatter(angles, landing)
# plt.scatter(population, vals)
# plt.title('Target distance')
# plt.xlabel('angle')
# plt.ylabel('distance')
# plt.show()

# %%
# 6 ways to hit a distance of 10, positions 10 and 30
print(traj(42))
print(traj(90))
print(traj(138))
print(traj(200))
print(traj(270))
print(traj(340))

plt.scatter([20], [0])
plt.show()
# Out:
# 29.92623946345737
# 10.0
# 9.92479374366168
# 9.980548362749733
# 10.0
# 29.981154042079705

# %%
# 6 ways to hit a distance of 8, positions 12 and 28
print(traj(49))
print(traj(86))
print(traj(148))
print(traj(188))
print(traj(276))
print(traj(331))

plt.scatter([20], [0])
plt.show()
# Out:
# 27.935210522745976
# 12.014322814078753
# 12.028531046006776
# 12.058965368527211
# 11.91659209109362
# 28.000023420817755

# %%
print(traj(170))
print(traj(168))
print(traj(169))
# Out:
# 13.574261258781135
# 13.601832910181503
# 13.58981060986924
